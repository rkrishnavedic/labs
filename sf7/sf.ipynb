# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 1:')

k=6.22e-19
n2=2000;
n1=n2;
n3=3000;

def dydx(x, y): 
    return k*((n1-x*0.5)**2)*((n2-x*0.5)**2)*((n3-x*0.75)**3);
def rungeKutta(x0, y0, x, h): 
    n = (int)((x - x0)/h)  
    y = y0 
    for i in range(1, n + 1): 
        k1 = h * dydx(x0, y) 
        k2 = h * dydx(x0 + 0.5 * h, y + 0.5 * k1) 
        k3 = h * dydx(x0 + 0.5 * h, y + 0.5 * k2) 
        k4 = h * dydx(x0 + h, y + k3) 
        y = y + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4) 
        x0 = x0 + h 
    return y 

print('Amount of KOH x(0.2s) = '+str(rungeKutta(0,0,0.2,0.01)));
# Out:
# Problem 1:
# Amount of KOH x(0.2s) = 53731.39630040521

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 2')

def f(t, y): 
    return -y+t+1;

def rungeKutta(x0, y0, x, h): 
    n = (int)((x - x0)/h)  
    y = y0 
    for i in range(1, n + 1): 
        k1 = h * f(x0, y) 
        k2 = h * f(x0 + 0.5 * h, y + 0.5 * k1) 
        k3 = h * f(x0 + 0.5 * h, y + 0.5 * k2) 
        k4 = h * f(x0 + h, y + k3) 
        y = y + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4) 
        x0 = x0 + h 
    return y 

def predict(x, y, h):  
    y1p = y + h * f(x, y); 
    return y1p; 
def correct(x, y, x1, y1, h): 
    e = 0.00001; 
    y1c = y1; 
  
    while (abs(y1c - y1) > e + 1): 
        y1 = y1c; 
        y1c = y + 0.5 * h * (f(x, y) + f(x1, y1)); 
    return y1c; 
  
def modiEuler(x, xn, y, h): 
    while (x < xn): 
        x1 = x + h; 
        y1p = predict(x, y, h); 
        y1c = correct(x, y, x1, y1p, h); 
        x = x1; 
        y = y1c; 
    return y;
xw=np.linspace(0,1,101);
yw=[0]*101;
xw1=np.linspace(0,1,101);
yw1=[0]*101;

for i in range(len(xw)):
    yw[i]=modiEuler(0,xw[i],1,0.01);

for i in range(len(xw1)):
    yw1[i]=rungeKutta(0,1,xw1[i],0.01);

plt.plot(xw,yw, label='modified Euler');
plt.plot(xw1,yw1, label='rungeKutta');
plt.legend();
plt.show();
# Out:
# Problem 2

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 3:')

print('part (a)');
def f1(t):
    return math.sqrt((t+1)**2+5)-1;

def f(x, y): 
    return (1+x)/(y+1);

def predict(x, y, h):  
    y1p = y + h * f(x, y); 
    return y1p; 
def correct(x, y, x1, y1, h): 
    e = 0.00001; 
    y1c = y1; 
  
    while (abs(y1c - y1) > e + 1): 
        y1 = y1c; 
        y1c = y + 0.5 * h * (f(x, y) + f(x1, y1)); 
    return y1c; 
  
def modiEuler(x, xn, y, h): 
    while (x < xn): 
        x1 = x + h; 
        y1p = predict(x, y, h); 
        y1c = correct(x, y, x1, y1p, h); 
        x = x1; 
        y = y1c; 
    return y;

xw=np.linspace(1,2,3);
yw=[0]*3;
xw1=np.linspace(1,2,101);
yw1=[0]*101;

for i in range(len(xw)):
    yw[i]=modiEuler(0,xw[i],1,0.5);

for i in range(len(xw1)):
    yw1[i]=f1(xw1[i]);

plt.plot(xw,yw, label='approx');
plt.plot(xw1,yw1, label='original');
plt.legend();
plt.show();
# Out:
# Problem 3:
# part (a)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 3:')

print('part (b)');
def f1(t):
    return (4+math.cos(2)-math.cos(2*t))/(2*(t**2));

def f(t, y): 
    return (math.sin(2*t)-2*t*y)/(2*t**2);

def predict(x, y, h):  
    y1p = y + h * f(x, y); 
    return y1p; 
def correct(x, y, x1, y1, h): 
    e = 0.00001; 
    y1c = y1; 
  
    while (abs(y1c - y1) > e + 1): 
        y1 = y1c; 
        y1c = y + 0.5 * h * (f(x, y) + f(x1, y1)); 
    return y1c; 
  
def modiEuler(x, xn, y, h): 
    while (x < xn): 
        x1 = x + h; 
        y1p = predict(x, y, h); 
        y1c = correct(x, y, x1, y1p, h); 
        x = x1; 
        y = y1c; 
    return y;

xw=np.linspace(1,2,5);
yw=[0]*5;
xw1=np.linspace(1,2,101);
yw1=[0]*101;

for i in range(len(xw)):
    yw[i]=modiEuler(1,xw[i],2,0.25);

for i in range(len(xw1)):
    yw1[i]=f1(xw1[i]);

plt.plot(xw,yw, label='approx');
plt.plot(xw1,yw1, label='original');
plt.legend();
plt.show();
# Out:
# Problem 3:
# part (b)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 4:')
def f(t, y): 
    return y-t**2+1;

def predict(x, y, h):  
    y1p = y + h * f(x, y); 
    return y1p; 
def correct(x, y, x1, y1, h): 
    e = 0.00001; 
    y1c = y1; 
  
    while (abs(y1c - y1) > e + 1): 
        y1 = y1c; 
        y1c = y + 0.5 * h * (f(x, y) + f(x1, y1)); 
    return y1c; 
  
def modiEuler(x, xn, y, h): 
    while (x < xn): 
        x1 = x + h; 
        y1p = predict(x, y, h); 
        y1c = correct(x, y, x1, y1p, h); 
        x = x1; 
        y = y1c; 
    return y;

def rungeKutta4(x0, y0, x, h): 
    n = (int)((x - x0)/h)  
    y = y0 
    for i in range(1, n + 1): 
        k1 = h * f(x0, y) 
        k2 = h * f(x0 + 0.5 * h, y + 0.5 * k1) 
        k3 = h * f(x0 + 0.5 * h, y + 0.5 * k2) 
        k4 = h * f(x0 + h, y + k3) 
        y = y + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4) 
        x0 = x0 + h 
    return y 

def rungeKutta2(x0, y0, x, h) :  
    n = round((x - x0) / h); 
    y = y0;  
      
    for i in range(1, n + 1) : 
        k1 = h * f(x0, y);  
        k2 = h * f(x0 + 0.5 * h, y + 0.5 * k1);  
        y = y + (1.0 / 6.0) * (k1 + 2 * k2);   
        x0 = x0 + h;  
  
    return y; 

xw=np.linspace(0,2,81);
yw=[0]*81;
yw1=[0]*81;
yw2=[0]*81;

for i in range(len(xw)):
    yw[i]=modiEuler(0,xw[i],0.5,0.025);
    yw1[i]=rungeKutta2(0,0.5, xw[i],0.05);
    yw2[i]=rungeKutta4(0,0.5, xw[i],0.1);


plt.plot(xw,yw, label='Euler');
plt.plot(xw,yw1,label="second order RK")
plt.plot(xw, yw2, label="4th order RK")
plt.legend();
plt.show();
# Out:
# Problem 4:

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 5:')

def g(t):
    return (t+1)**2-0.5*math.exp(t);
def f(t,yq):
    return yq-t**2+1;

def AB_Explicit_Meth(h,ya, N):
    t = np.linspace(0, 2, N+1) #array intialized to hold mesh points t
    
    y = [0]*(N+1); #array to hold Midpoint Method approximated y values
    
    y[0] = ya           #intial condition 
    
    
    #using RK4 to obtain the first 3 points
    for i in range(0,N):    #establishes iteration for N mesh points
        if i in range(0,3): #for the first 3 iterations in N, runge kutta fourth order holds
            
            k1 = h * f(t[i],y[i])
            k2 = h * f(t[i] + (h/2.0), y[i] +(k1/2.0))
            k3 = h * f(t[i] + (h/2.0), y[i] + (k2/2.0))
            k4 = h * f(t[i] + h, y[i] + k3)
        
            y[i + 1] = y[i] + (k1 + 2.0*k2 + 2.0*k3 + k4)/6.0
        else:       #else, N>3, explicit AB method
        
            y[i + 1] = y[i] + h*(55.0 * f(t[i],y[i]) - 59.0 * f(t[i-1],y[i-1]) + 37.0 * f(t[i-2],y[i-2]) - 9.0 * f(t[i-3],y[i-3]))/24.0
    
    return t,y;

xw, yw = AB_Explicit_Meth(0.2,0.5,11);
plt.plot(xw,yw, label="AB Explicit");
plt.legend();
plt.show();
# Out:
# Problem 5:

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 6:')
print('part (a)');
def g(t):
    return (2*t+1)/(1+t**2);
def f(t,yq):
    return (2-2*yq*t)/(1+t**2);

def AB_Explicit_Meth(h,ya, N):
    t = np.linspace(0, 1, N+1) #array intialized to hold mesh points t
    
    y = [0]*(N+1); #array to hold Midpoint Method approximated y values
    
    y[0] = ya           #intial condition 
    
    
    #using RK4 to obtain the first 3 points
    for i in range(0,N):    #establishes iteration for N mesh points
        if i in range(0,3): #for the first 3 iterations in N, runge kutta fourth order holds
            
            k1 = h * f(t[i],y[i])
            k2 = h * f(t[i] + (h/2.0), y[i] +(k1/2.0))
            k3 = h * f(t[i] + (h/2.0), y[i] + (k2/2.0))
            k4 = h * f(t[i] + h, y[i] + k3)
        
            y[i + 1] = y[i] + (k1 + 2.0*k2 + 2.0*k3 + k4)/6.0
        else:       #else, N>3, explicit AB method
        
            y[i + 1] = y[i] + h*(55.0 * f(t[i],y[i]) - 59.0 * f(t[i-1],y[i-1]) + 37.0 * f(t[i-2],y[i-2]) - 9.0 * f(t[i-3],y[i-3]))/24.0
    
    return t,y;

xw1=np.linspace(0,1,101);
yw1=[0]*101;
for i in range(101):
    yw1[i]=g(xw1[i]);

xw, yw = AB_Explicit_Meth(0.1,1,11);
plt.plot(xw,yw, label="AB Explicit");
plt.plot(xw1,yw1,label="original");
plt.legend();
plt.show();
# Out:
# Problem 6:
# part (a)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 6:')
print('part (b)');
def g(t):
    return -1/(math.log(1+t));
def f(t,yq):
    return (yq**2)/(1+t);

def AB_Explicit_Meth(h,ya, N):
    t = np.linspace(1, 2, N+1) #array intialized to hold mesh points t
    
    y = [0]*(N+1); #array to hold Midpoint Method approximated y values
    
    y[0] = ya           #intial condition 
    
    
    #using RK4 to obtain the first 3 points
    for i in range(0,N):    #establishes iteration for N mesh points
        if i in range(0,3): #for the first 3 iterations in N, runge kutta fourth order holds
            
            k1 = h * f(t[i],y[i])
            k2 = h * f(t[i] + (h/2.0), y[i] +(k1/2.0))
            k3 = h * f(t[i] + (h/2.0), y[i] + (k2/2.0))
            k4 = h * f(t[i] + h, y[i] + k3)
        
            y[i + 1] = y[i] + (k1 + 2.0*k2 + 2.0*k3 + k4)/6.0
        else:       #else, N>3, explicit AB method
        
            y[i + 1] = y[i] + h*(55.0 * f(t[i],y[i]) - 59.0 * f(t[i-1],y[i-1]) + 37.0 * f(t[i-2],y[i-2]) - 9.0 * f(t[i-3],y[i-3]))/24.0
    
    return t,y;

xw1=np.linspace(1,2,101);
yw1=[0]*101;
for i in range(101):
    yw1[i]=g(xw1[i]);

xw, yw = AB_Explicit_Meth(0.1,-1/math.log(2),11);
plt.plot(xw,yw, label="AB Explicit");
plt.plot(xw1,yw1,label="original");
plt.legend();
plt.show();
# Out:
# Problem 6:
# part (b)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 6:')
print('part (c)');
def g(t):
    return (2+t)/(1-t);
def f(t,yq):
    return (yq**2+yq)/(t);

def AB_Explicit_Meth(h,ya, N):
    t = np.linspace(1, 3, N+1) #array intialized to hold mesh points t
    
    y = [0]*(N+1); #array to hold Midpoint Method approximated y values
    
    y[0] = ya           #intial condition 
    
    
    #using RK4 to obtain the first 3 points
    for i in range(0,N):    #establishes iteration for N mesh points
        if i in range(0,3): #for the first 3 iterations in N, runge kutta fourth order holds
            
            k1 = h * f(t[i],y[i])
            k2 = h * f(t[i] + (h/2.0), y[i] +(k1/2.0))
            k3 = h * f(t[i] + (h/2.0), y[i] + (k2/2.0))
            k4 = h * f(t[i] + h, y[i] + k3)
        
            y[i + 1] = y[i] + (k1 + 2.0*k2 + 2.0*k3 + k4)/6.0
        else:       #else, N>3, explicit AB method
        
            y[i + 1] = y[i] + h*(55.0 * f(t[i],y[i]) - 59.0 * f(t[i-1],y[i-1]) + 37.0 * f(t[i-2],y[i-2]) - 9.0 * f(t[i-3],y[i-3]))/24.0
    
    return t,y;

xw1=np.linspace(1,3,101);
yw1=[0]*101;
for i in range(101):
    yw1[i]=g(xw1[i]);

xw, yw = AB_Explicit_Meth(0.2,-2,11);
plt.plot(xw,yw, label="AB Explicit");
plt.plot(xw1,yw1,label="original");
plt.legend();
plt.show();
# Out:
# Problem 6:
# part (c)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in double_scalars

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

print('Problem 7:')

def f(t,yq):
    return yq-t**2+1;

def AB_Explicit_Meth(h,ya, N):
    t = np.linspace(0, 2, N+1) #array intialized to hold mesh points t
    
    y = [0]*(N+1); #array to hold Midpoint Method approximated y values
    
    y[0] = ya           #intial condition 
    
    
    #using RK4 to obtain the first 3 points
    for i in range(0,N):    #establishes iteration for N mesh points
        if i in range(0,3): #for the first 3 iterations in N, runge kutta fourth order holds
            
            k1 = h * f(t[i],y[i])
            k2 = h * f(t[i] + (h/2.0), y[i] +(k1/2.0))
            k3 = h * f(t[i] + (h/2.0), y[i] + (k2/2.0))
            k4 = h * f(t[i] + h, y[i] + k3)
        
            y[i + 1] = y[i] + (k1 + 2.0*k2 + 2.0*k3 + k4)/6.0
        else:       #else, N>3, explicit AB method
        
            y[i + 1] = y[i] + h*(55.0 * f(t[i],y[i]) - 59.0 * f(t[i-1],y[i-1]) + 37.0 * f(t[i-2],y[i-2]) - 9.0 * f(t[i-3],y[i-3]))/24.0
    
    return t,y;

xw, yw = AB_Explicit_Meth(0.2,0.5,11);
plt.plot(xw,yw, label="AB Explicit");

plt.legend();
plt.show();
# Out:
# Problem 7:
